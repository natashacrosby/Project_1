# %%
import pandas as pd
import scipy.stats as stats

# %%
df = pd.read_csv("GCP_Release_1.csv")
df.head()
# Out:
#    FIPS Countyname Postal  LineCode                             IndustryName  \
# 0   NaN        NaN    NaN       NaN                                      NaN
# 1   NaN        NaN    NaN       NaN                                      NaN
# 2  1001    Autauga     AL       1.0                           All Industries
# 3  1001    Autauga     AL       2.0       Private goods-producing industries
# 4  1001    Autauga     AL       3.0    Private services-providing industries
#
#   Gross domestic product (GDP) by county Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0                 (thousands of dollars)        NaN        NaN        NaN
# 1                                   2012       2013       2014       2015
# 2                                1383941    1363368    1402516    1539406
# 3                                 286396     310468     323582     346355
# 4                                 948490     904599     928438    1037309

# %%
del df['FIPS']
del df['Unnamed: 6']
del df['Unnamed: 7']
del df['Gross domestic product (GDP) by county']

# %%
df.head()
# Out:
#   Countyname Postal  LineCode                             IndustryName  \
# 0        NaN    NaN       NaN                                      NaN
# 1        NaN    NaN       NaN                                      NaN
# 2    Autauga     AL       1.0                           All Industries
# 3    Autauga     AL       2.0       Private goods-producing industries
# 4    Autauga     AL       3.0    Private services-providing industries
#
#   Unnamed: 8
# 0        NaN
# 1       2015
# 2    1539406
# 3     346355
# 4    1037309

# %%
df.drop([0,1], axis=0).head()
# Out:
#   Countyname Postal  LineCode                             IndustryName  \
# 2    Autauga     AL       1.0                           All Industries
# 3    Autauga     AL       2.0       Private goods-producing industries
# 4    Autauga     AL       3.0    Private services-providing industries
# 5    Autauga     AL       4.0    Government and government enterprises
# 6    Baldwin     AL       1.0                           All Industries
#
#   Unnamed: 8
# 2    1539406
# 3     346355
# 4    1037309
# 5     155742
# 6    6436107

# %%
# Python
# delete all rows with column 'Age' has value 30 to 40 
indexnames = df[(df['LineCode'] > 1.0)].index
df.drop(indexnames , inplace=True)
df.drop([0,1], axis=0).head()
# Out:
#    Countyname Postal  LineCode    IndustryName Unnamed: 8
# 2     Autauga     AL       1.0  All Industries    1539406
# 6     Baldwin     AL       1.0  All Industries    6436107
# 10    Barbour     AL       1.0  All Industries     743779
# 14       Bibb     AL       1.0  All Industries     322307
# 18     Blount     AL       1.0  All Industries     819608
