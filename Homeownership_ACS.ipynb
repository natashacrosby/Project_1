# %%
import pandas as pd
import scipy.stats as stats

# %%
df = pd.read_csv("Homeownership_ACS.csv")
df.head()
# Out:
#            GEO.id GEO.id2        GEO.display-label  \
# 0              Id     Id2                Geography
# 1  0500000US01001    1001  Autauga County, Alabama
# 2  0500000US01003    1003  Baldwin County, Alabama
# 3  0500000US01005    1005  Barbour County, Alabama
# 4  0500000US01007    1007     Bibb County, Alabama
#
#                        HC01_EST_VC02  \
# 0  Total; Estimate; Total households
# 1                              21054
# 2                              76133
# 3                               9191
# 4                               6916
#
#                               HC01_MOE_VC02  \
# 0  Total; Margin of Error; Total households
# 1                                       387
# 2                                      1153
# 3                                       337
# 4                                       308
#
#                                        HC02_EST_VC02  \
# 0  Married-couple family household; Estimate; Tot...
# ...

# %%
df.set_index("GEO.display-label", inplace=True)
df.head()
# Out:
#                                  GEO.id GEO.id2  \
# GEO.display-label
# Geography                            Id     Id2
# Autauga County, Alabama  0500000US01001    1001
# Baldwin County, Alabama  0500000US01003    1003
# Barbour County, Alabama  0500000US01005    1005
# Bibb County, Alabama     0500000US01007    1007
#
#                                              HC01_EST_VC02  \
# GEO.display-label
# Geography                Total; Estimate; Total households
# Autauga County, Alabama                              21054
# Baldwin County, Alabama                              76133
# Barbour County, Alabama                               9191
# Bibb County, Alabama                                  6916
#
#                                                     HC01_MOE_VC02  \
# GEO.display-label
# Geography                Total; Margin of Error; Total households
# Autauga County, Alabama                                       387
# ...

# %%
df.drop(df.iloc[:, 0:181], inplace = True, axis = 1)
df.drop(df.iloc[:, 3:22], inplace = True,axis=1)
df.head()
# Out:
#                                                              HC05_MOE_VC29  \
# GEO.display-label
# Geography                Nonfamily household; Margin of Error; UNITS IN...
# Autauga County, Alabama                                                4.2
# Baldwin County, Alabama                                                1.8
# Barbour County, Alabama                                                3.8
# Bibb County, Alabama                                                   7.2
#
#                                                              HC01_EST_VC32  \
# GEO.display-label
# Geography                Total; Estimate; HOUSING TENURE - Owner-occupi...
# Autauga County, Alabama                                               73.3
# Baldwin County, Alabama                                               72.9
# Barbour County, Alabama                                               62.5
# Bibb County, Alabama                                                  75.4
#
# ...

# %%
del df['HC05_MOE_VC29']
del df['HC01_MOE_VC32']
df.head()
# Out:
#                                                              HC01_EST_VC32
# GEO.display-label
# Geography                Total; Estimate; HOUSING TENURE - Owner-occupi...
# Autauga County, Alabama                                               73.3
# Baldwin County, Alabama                                               72.9
# Barbour County, Alabama                                               62.5
# Bibb County, Alabama                                                  75.4

# %%
df.drop(['Geography'], axis=0, inplace = True)

# %%
df.reset_index(drop=False, inplace = True)

# %%
HOR = df.rename(columns={"GEO.display-label": "county", "HC01_EST_VC32": "HOR"})
HOR
# Out:
#                             county   HOR
# 0          Autauga County, Alabama  73.3
# 1          Baldwin County, Alabama  72.9
# 2          Barbour County, Alabama  62.5
# 3             Bibb County, Alabama  75.4
# 4           Blount County, Alabama  78.5
# 5          Bullock County, Alabama    70
# 6           Butler County, Alabama  70.1
# 7          Calhoun County, Alabama  69.4
# 8         Chambers County, Alabama  66.5
# 9         Cherokee County, Alabama  78.1
# 10         Chilton County, Alabama  75.3
# 11         Choctaw County, Alabama  80.2
# 12          Clarke County, Alabama    66
# 13            Clay County, Alabama  76.5
# 14        Cleburne County, Alabama  74.4
# 15          Coffee County, Alabama  65.4
# 16         Colbert County, Alabama  72.8
# 17         Conecuh County, Alabama  77.6
# 18           Coosa County, Alabama  80.3
# 19       Covington County, Alabama  75.1
# 20        Crenshaw County, Alabama    71
# 21         Cullman County, Alabama  74.8
# ...
