# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
from us import states


df = pd.read_csv("poverty.csv")

df.head()
# Out:
#            GEO.id GEO.id2        GEO.display-label         HD01_VD01  \
# 0              Id     Id2                Geography  Estimate; Total:
# 1  0500000US01001    1001  Autauga County, Alabama              1425
# 2  0500000US01003    1003  Baldwin County, Alabama              3418
# 3  0500000US01005    1005  Barbour County, Alabama               671
# 4  0500000US01007    1007     Bibb County, Alabama               787
#
#                  HD02_VD01                                          HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Income in the past 12 months below p...
# 1                      384                                                115
# 2                      537                                                508
# 3                      128                                                298
# 4                      265                                                194
#
#                                            HD02_VD02  \
# 0  Margin of Error; Income in the past 12 months ...
# 1                                                 63
# 2                                                176
# 3                                                111
# 4                                                127
#
#                                            HD01_VD03  \
# 0  Estimate; Income in the past 12 months below p...
# 1                                                 86
# 2                                                254
# 3                                                198
# 4                                                179
#
#                                            HD02_VD03  \
# 0  Margin of Error; Income in the past 12 months ...
# 1                                                 55
# 2                                                130
# 3                                                 86
# 4                                                129
#
#                                            HD01_VD04  ...  \
# 0  Estimate; Income in the past 12 months below p...  ...
# 1                                                 61  ...
# 2                                                141  ...
# 3                                                147  ...
# 4                                                120  ...
#
#                                            HD01_VD07  \
# 0  Estimate; Income in the past 12 months at or a...
# 1                                               1310
# 2                                               2910
# 3                                                373
# 4                                                593
#
#                                            HD02_VD07  \
# 0  Margin of Error; Income in the past 12 months ...
# 1                                                386
# 2                                                507
# 3                                                 85
# 4                                                243
#
#                                            HD01_VD08  \
# 0  Estimate; Income in the past 12 months at or a...
# 1                                                759
# 2                                               1455
# 3                                                155
# 4                                                434
#
#                                            HD02_VD08  \
# 0  Margin of Error; Income in the past 12 months ...
# 1                                                323
# 2                                                363
# 3                                                 66
# 4                                                209
#
#                                            HD01_VD09  \
# 0  Estimate; Income in the past 12 months at or a...
# 1                                                510
# 2                                                772
# 3                                                 52
# 4                                                367
#
#                                            HD02_VD09  \
# 0  Margin of Error; Income in the past 12 months ...
# 1                                                271
# 2                                                256
# 3                                                 29
# 4                                                203
#
#                                            HD01_VD10  \
# 0  Estimate; Income in the past 12 months at or a...
# 1                                                249
# 2                                                683
# 3                                                103
# 4                                                 67
#
#                                            HD02_VD10  \
# 0  Margin of Error; Income in the past 12 months ...
# 1                                                134
# 2                                                211
# 3                                                 54
# 4                                                 51
#
#                                            HD01_VD11  \
# 0  Estimate; Income in the past 12 months at or a...
# 1                                                551
# 2                                               1455
# 3                                                218
# 4                                                159
#
#                                            HD02_VD11
# 0  Margin of Error; Income in the past 12 months ...
# 1                                                191
# 2                                                324
# 3                                                 70
# 4                                                101
#
# [5 rows x 25 columns]

# %%
df.set_index("GEO.display-label", inplace=True)
df.head()
# Out:
#                                  GEO.id GEO.id2         HD01_VD01  \
# GEO.display-label
# Geography                            Id     Id2  Estimate; Total:
# Autauga County, Alabama  0500000US01001    1001              1425
# Baldwin County, Alabama  0500000US01003    1003              3418
# Barbour County, Alabama  0500000US01005    1005               671
# Bibb County, Alabama     0500000US01007    1007               787
#
#                                        HD02_VD01  \
# GEO.display-label
# Geography                Margin of Error; Total:
# Autauga County, Alabama                      384
# Baldwin County, Alabama                      537
# Barbour County, Alabama                      128
# Bibb County, Alabama                         265
#
#                                                                  HD01_VD02  \
# GEO.display-label
# Geography                Estimate; Income in the past 12 months below p...
# Autauga County, Alabama                                                115
# Baldwin County, Alabama                                                508
# Barbour County, Alabama                                                298
# Bibb County, Alabama                                                   194
#
#                                                                  HD02_VD02  \
# GEO.display-label
# Geography                Margin of Error; Income in the past 12 months ...
# Autauga County, Alabama                                                 63
# Baldwin County, Alabama                                                176
# Barbour County, Alabama                                                111
# Bibb County, Alabama                                                   127
#
#                                                                  HD01_VD03  \
# GEO.display-label
# Geography                Estimate; Income in the past 12 months below p...
# Autauga County, Alabama                                                 86
# Baldwin County, Alabama                                                254
# Barbour County, Alabama                                                198
# Bibb County, Alabama                                                   179
#
#                                                                  HD02_VD03  \
# GEO.display-label
# Geography                Margin of Error; Income in the past 12 months ...
# Autauga County, Alabama                                                 55
# Baldwin County, Alabama                                                130
# Barbour County, Alabama                                                 86
# Bibb County, Alabama                                                   129
#
#                                                                  HD01_VD04  \
# GEO.display-label
# Geography                Estimate; Income in the past 12 months below p...
# Autauga County, Alabama                                                 61
# Baldwin County, Alabama                                                141
# Barbour County, Alabama                                                147
# Bibb County, Alabama                                                   120
#
#                                                                  HD02_VD04  \
# GEO.display-label
# Geography                Margin of Error; Income in the past 12 months ...
# Autauga County, Alabama                                                 48
# Baldwin County, Alabama                                                 96
# Barbour County, Alabama                                                 77
# Bibb County, Alabama                                                    87
#
#                          ...  \
# GEO.display-label        ...
# Geography                ...
# Autauga County, Alabama  ...
# Baldwin County, Alabama  ...
# Barbour County, Alabama  ...
# Bibb County, Alabama     ...
#
#                                                                  HD01_VD07  \
# GEO.display-label
# Geography                Estimate; Income in the past 12 months at or a...
# Autauga County, Alabama                                               1310
# Baldwin County, Alabama                                               2910
# Barbour County, Alabama                                                373
# Bibb County, Alabama                                                   593
#
#                                                                  HD02_VD07  \
# GEO.display-label
# Geography                Margin of Error; Income in the past 12 months ...
# Autauga County, Alabama                                                386
# Baldwin County, Alabama                                                507
# Barbour County, Alabama                                                 85
# Bibb County, Alabama                                                   243
#
#                                                                  HD01_VD08  \
# GEO.display-label
# Geography                Estimate; Income in the past 12 months at or a...
# Autauga County, Alabama                                                759
# Baldwin County, Alabama                                               1455
# Barbour County, Alabama                                                155
# Bibb County, Alabama                                                   434
#
#                                                                  HD02_VD08  \
# GEO.display-label
# Geography                Margin of Error; Income in the past 12 months ...
# Autauga County, Alabama                                                323
# Baldwin County, Alabama                                                363
# Barbour County, Alabama                                                 66
# Bibb County, Alabama                                                   209
#
#                                                                  HD01_VD09  \
# GEO.display-label
# Geography                Estimate; Income in the past 12 months at or a...
# Autauga County, Alabama                                                510
# Baldwin County, Alabama                                                772
# Barbour County, Alabama                                                 52
# Bibb County, Alabama                                                   367
#
#                                                                  HD02_VD09  \
# GEO.display-label
# Geography                Margin of Error; Income in the past 12 months ...
# Autauga County, Alabama                                                271
# Baldwin County, Alabama                                                256
# Barbour County, Alabama                                                 29
# Bibb County, Alabama                                                   203
#
#                                                                  HD01_VD10  \
# GEO.display-label
# Geography                Estimate; Income in the past 12 months at or a...
# Autauga County, Alabama                                                249
# Baldwin County, Alabama                                                683
# Barbour County, Alabama                                                103
# Bibb County, Alabama                                                    67
#
#                                                                  HD02_VD10  \
# GEO.display-label
# Geography                Margin of Error; Income in the past 12 months ...
# Autauga County, Alabama                                                134
# Baldwin County, Alabama                                                211
# Barbour County, Alabama                                                 54
# Bibb County, Alabama                                                    51
#
#                                                                  HD01_VD11  \
# GEO.display-label
# Geography                Estimate; Income in the past 12 months at or a...
# Autauga County, Alabama                                                551
# Baldwin County, Alabama                                               1455
# Barbour County, Alabama                                                218
# Bibb County, Alabama                                                   159
#
#                                                                  HD02_VD11
# GEO.display-label
# Geography                Margin of Error; Income in the past 12 months ...
# Autauga County, Alabama                                                191
# Baldwin County, Alabama                                                324
# Barbour County, Alabama                                                 70
# Bibb County, Alabama                                                   101
#
# [5 rows x 24 columns]

# %%
df.drop(df.columns[0:2], inplace = True, axis = 1)
df.drop(df.columns[4:22], inplace = True, axis = 1)
df.head()
# Out:
#                                 HD01_VD01                HD02_VD01  \
# GEO.display-label
# Geography                Estimate; Total:  Margin of Error; Total:
# Autauga County, Alabama              1425                      384
# Baldwin County, Alabama              3418                      537
# Barbour County, Alabama               671                      128
# Bibb County, Alabama                  787                      265
#
#                                                                  HD01_VD02  \
# GEO.display-label
# Geography                Estimate; Income in the past 12 months below p...
# Autauga County, Alabama                                                115
# Baldwin County, Alabama                                                508
# Barbour County, Alabama                                                298
# Bibb County, Alabama                                                   194
#
#                                                                  HD02_VD02
# GEO.display-label
# Geography                Margin of Error; Income in the past 12 months ...
# Autauga County, Alabama                                                 63
# Baldwin County, Alabama                                                176
# Barbour County, Alabama                                                111
# Bibb County, Alabama                                                   127

# %%
df.drop(df.columns[1:4], inplace = True, axis = 1)
df.head()
# Out:
#                                 HD01_VD01
# GEO.display-label
# Geography                Estimate; Total:
# Autauga County, Alabama              1425
# Baldwin County, Alabama              3418
# Barbour County, Alabama               671
# Bibb County, Alabama                  787

# %%
renamed_df = df.rename(columns={"HD01_VD01":"Total"})
renamed_df.head()
# Out:
#                                     Total
# GEO.display-label
# Geography                Estimate; Total:
# Autauga County, Alabama              1425
# Baldwin County, Alabama              3418
# Barbour County, Alabama               671
# Bibb County, Alabama                  787

# %%
renamed_df.drop(['Geography'], axis = 0, inplace = True)

# %%
renamed_df.reset_index(drop=False, inplace = True)

# %%
poverty1_df = renamed_df.rename(columns={"GEO.display-label":"County"})
poverty1_df.head()
# Out:
#                     County Total
# 0  Autauga County, Alabama  1425
# 1  Baldwin County, Alabama  3418
# 2  Barbour County, Alabama   671
# 3     Bibb County, Alabama   787
# 4   Blount County, Alabama  1667

# %%
poverty2 =poverty1_df.replace(regex=[' County'], value='')
poverty2.head()
# Out:
#              County Total
# 0  Autauga, Alabama  1425
# 1  Baldwin, Alabama  3418
# 2  Barbour, Alabama   671
# 3     Bibb, Alabama   787
# 4   Blount, Alabama  1667

# %%
POV3 = poverty2['County'].str.split(pat = ",",expand= True)
poverty2['county']=POV3[0]
poverty2['state']=POV3[1]
poverty2.drop(columns =["County"], inplace = True)
poverty2.head()
# Out:
#   Total   county     state
# 0  1425  Autauga   Alabama
# 1  3418  Baldwin   Alabama
# 2   671  Barbour   Alabama
# 3   787     Bibb   Alabama
# 4  1667   Blount   Alabama

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Palau': 'PW',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

poverty2['state'] = poverty2['state'].map(lambda name: us_state_abbrev[name.strip()])
poverty2.head()
# Out:
#   Total   county state
# 0  1425  Autauga    AL
# 1  3418  Baldwin    AL
# 2   671  Barbour    AL
# 3   787     Bibb    AL
# 4  1667   Blount    AL

# %%
poverty2['county'] = poverty2['county'].map(str) + ", " + poverty2['state']
poverty2 = poverty2[["Total", "county"]]
poverty2.head()
# Out:
#   Total       county
# 0  1425  Autauga, AL
# 1  3418  Baldwin, AL
# 2   671  Barbour, AL
# 3   787     Bibb, AL
# 4  1667   Blount, AL

# %%
poverty2.to_csv("Poverty_Total_Clean2.csv")
